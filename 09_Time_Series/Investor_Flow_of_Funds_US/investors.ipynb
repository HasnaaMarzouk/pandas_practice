# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
investors = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
investors.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2022-07-06         10167              NaN          3058     NaN
# 1  2022-07-13          7409              NaN          2808     NaN
# 2  2022-07-20          3468              NaN           102     NaN
# 3  2022-07-27         14213              NaN          9667     NaN
# 4  2022-08-03          9786              NaN          4016     NaN
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0         842           NaN            2216    NaN
# 1        2067           NaN             741    NaN
# 2        -417           NaN             519    NaN
# 3        8598           NaN            1069    NaN
# 4        3079           NaN             937    NaN

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
investors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             118 non-null    object
#  1   Total Equity     118 non-null    int64
#  2   Domestic Equity  0 non-null      float64
#  3   World Equity     118 non-null    int64
#  4   Hybrid           0 non-null      float64
#  5   Total Bond       118 non-null    int64
#  6   Taxable Bond     0 non-null      float64
#  7   Municipal Bond   118 non-null    int64
#  8   Total            0 non-null      float64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 8.4+ KB

# %%
investors.columns
# Out:
# Index(['Date', 'Total Equity', 'Domestic Equity', 'World Equity', 'Hybrid',
#        'Total Bond', 'Taxable Bond', 'Municipal Bond', 'Total'],
#       dtype='object')

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
investors.set_index('Date', inplace=True)
investors.head()
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-07-06         10167              NaN          3058     NaN         842
# 2022-07-13          7409              NaN          2808     NaN        2067
# 2022-07-20          3468              NaN           102     NaN        -417
# 2022-07-27         14213              NaN          9667     NaN        8598
# 2022-08-03          9786              NaN          4016     NaN        3079
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-07-06           NaN            2216    NaN
# 2022-07-13           NaN             741    NaN
# 2022-07-20           NaN             519    NaN
# 2022-07-27           NaN            1069    NaN
# 2022-08-03           NaN             937    NaN

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
investors.index.dtype
# Out:
# dtype('O')

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
investors.index = pd.to_datetime(investors.index)
investors.index.dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
investors.resample('M').sum()
# Out:
# /tmp/ipykernel_37993/3232482421.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   investors.resample('M').sum()
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-07-31         35257              0.0         15635     0.0       11090
# 2022-08-31         48596              0.0         32348     0.0       33705
# 2022-09-30         13775              0.0         10324     0.0       11629
# 2022-10-31         82879              0.0         55644     0.0       47435
# 2022-11-30         82731              0.0         54314     0.0       37348
# 2022-12-31         40451              0.0         29124     0.0       18273
# 2023-01-31         34891              0.0          7849     0.0       -9996
# 2023-02-28         13284              0.0         16508     0.0        6243
# 2023-03-31         28861              0.0          3713     0.0        2500
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
investors.dropna(how='all', inplace=True)
investors.head()
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-07-06         10167              NaN          3058     NaN         842
# 2022-07-13          7409              NaN          2808     NaN        2067
# 2022-07-20          3468              NaN           102     NaN        -417
# 2022-07-27         14213              NaN          9667     NaN        8598
# 2022-08-03          9786              NaN          4016     NaN        3079
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-07-06           NaN            2216    NaN
# 2022-07-13           NaN             741    NaN
# 2022-07-20           NaN             519    NaN
# 2022-07-27           NaN            1069    NaN
# 2022-08-03           NaN             937    NaN

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
investors.resample('Y').sum()
# Out:
# /tmp/ipykernel_37993/1662318042.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   investors.resample('Y').sum()
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-12-31        303689              0.0        197389     0.0      159480
# 2023-12-31        577223              0.0        384006     0.0      301790
# 2024-12-31        501341              0.0        362632     0.0      312430
# 2025-12-31        204465              0.0        126778     0.0       90915
# 2026-12-31        296299              0.0        177177     0.0       85818
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-12-31           0.0           37908    0.0
# 2023-12-31           0.0           82214    0.0
# 2024-12-31           0.0           50200    0.0
# 2025-12-31           0.0           35862    0.0
# 2026-12-31           0.0           91358    0.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# What is the total 'Total Equity' across all available dates?

# %%
total_equity_sum = investors['Total Equity'].sum()
total_equity_sum
# Out:
# np.int64(1883017)
