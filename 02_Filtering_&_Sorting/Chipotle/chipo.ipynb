# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
data = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = data

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo['item_price'] = (chipo['item_price']).astype(str).str.replace('$', '').astype(float)

# %%
chipo.item_price
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
more_than_10 = (chipo['item_price'] > 10).sum()

# %%
more_than_10
# Out:
# np.int64(1130)

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
pd.crosstab(chipo["item_name"],["item_price"])
# Out:
# col_0                                  item_price
# item_name
# 6 Pack Soft Drink                              54
# Barbacoa Bowl                                  66
# Barbacoa Burrito                               91
# Barbacoa Crispy Tacos                          11
# Barbacoa Salad Bowl                            10
# Barbacoa Soft Tacos                            25
# Bottled Water                                 162
# Bowl                                            2
# Burrito                                         6
# Canned Soda                                   104
# Canned Soft Drink                             301
# Carnitas Bowl                                  68
# Carnitas Burrito                               59
# Carnitas Crispy Tacos                           7
# Carnitas Salad                                  1
# Carnitas Salad Bowl                             6
# Carnitas Soft Tacos                            40
# Chicken Bowl                                  726
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
pd.crosstab(chipo["item_name"],["item_price"]).sort_values("item_name")
# Out:
# col_0                                  item_price
# item_name
# 6 Pack Soft Drink                              54
# Barbacoa Bowl                                  66
# Barbacoa Burrito                               91
# Barbacoa Crispy Tacos                          11
# Barbacoa Salad Bowl                            10
# Barbacoa Soft Tacos                            25
# Bottled Water                                 162
# Bowl                                            2
# Burrito                                         6
# Canned Soda                                   104
# Canned Soft Drink                             301
# Carnitas Bowl                                  68
# Carnitas Burrito                               59
# Carnitas Crispy Tacos                           7
# Carnitas Salad                                  1
# Carnitas Salad Bowl                             6
# Carnitas Soft Tacos                            40
# Chicken Bowl                                  726
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
#solution 1
chipo.groupby("item_name").max().sort_values("item_price", ascending=False).head(1)
# Out:
#                               order_id  quantity choice_description  \
# item_name
# Chips and Fresh Tomato Salsa      1790        15                NaN
#
#                               item_price
# item_name
# Chips and Fresh Tomato Salsa       44.25

# %%
#solution 2
chipo.sort_values("item_price", ascending=False).head(1)['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo.groupby("item_name").sum().loc["Veggie Salad Bowl", "quantity"]
# Out:
# np.int64(18)

# %%
chipo.item_name.value_counts()["Veggie Salad Bowl"]
# Out:
# np.int64(18)

# %% [markdown]
# Step 9. How many times did someone order more than one Canned Soda?

# %%
(chipo[chipo['item_name'] == "Canned Soda"]['quantity'] > 1).sum()
# Out:
# np.int64(20)
